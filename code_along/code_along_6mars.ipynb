# %% [markdown]
# https://en.wikipedia.org/wiki/2024_Summer_Olympics_medal_table

# %%
import pandas as pd

url = "https://en.wikipedia.org/wiki/2024_Summer_Olympics_medal_table"

#df_country = pd.read_html(url)[3]
df_country = pd.read_html(url, index_col=0)[3]

df_country.index.name = None

#type(df_country)

#df_country.head()

df_country = df_country[:-1]

df_country["NOC"] = df_country["NOC"].str.replace(r'[^A-Za-z\s]', "", regex=True)
#df_country["NOC"] = df_country["NOC"].str.replacer("*", "", regex=True)

#df_country["NOC"].unique()

df_country
# Out:
#                      NOC  Gold  Silver  Bronze  Total
# 1          United States    40      44      42    126
# 2                  China    40      27      24     91
# 3                  Japan    20      12      13     45
# 4              Australia    18      19      16     53
# 5                 France    16      26      22     64
# ..                   ...   ...     ...     ...    ...
# 84                 Qatar     0       0       1      1
# 84  Refugee Olympic Team     0       0       1      1
# 84             Singapore     0       0       1      1
# 84              Slovakia     0       0       1      1
# 84                Zambia     0       0       1      1
#
# [92 rows x 5 columns]

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 1 to 84
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     92 non-null     object
#  1   Gold    92 non-null     int64
#  2   Silver  92 non-null     int64
#  3   Bronze  92 non-null     int64
#  4   Total   92 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 6.4+ KB

# %%
fig_country = df_country.plot(kind="bar", x = "NOC", y = "Total")
